# %%
# 1Q.
# price = 12500
# discount = price * 10 / 100
# price_after_discount = price - discount
# gst = price_after_discount * 18 / 100
# final_amount = price_after_discount + gst
# print("Final Payable Amount =", final_amount)

# 2Q.
# order_value = 8000
# if order_value >= 10000;
#     print("The order qualifies for free delivery.")
# else: print("The order does not qualify for free delivery.")

# 3Q.
# order1 = 45000
# order2 = 72000
# if order1 > order2:
#     print("Order 1 has the higher value.")
# elif order2 > order1:
#     print("Order 2 has the higher value.")
# else: print("Both orders have the same value.")

# 4Q.
# order_amount = 50000
# payment_mode = "Online"
# if order_amount > 50000 and payment_mode == "Online";
#     print("Order is eligible for the special offer.")
# else: print("Order is not eligible for the special offer.")

# 5Q.
# total_items = 37
# box_capacity = 6
# full_boxes = total_items // box_capacity
# remaining_items = total_items % box_capacity
# print("full boxes required", full_boxes)
# print("remaining_items", remaining_items)

# 6Q.
# amount = float(input("Enter the Order amount"))
# if amount > 100000:
#     print("Premium Order")
# elif amount > 50000 and amount < 100000:
#     print("Standard Order")
# else: print("Basic Order")

# 7Q.
# Product stock count
# stock = int(input("Enter stock count: "))
# if stock == 0:
#     print("Out of Stock")
# else:
#     print("Available")

# 8Q.
# isDelivered = True
# return_days = 7
# if isDelivered and return_days <= 5:
#     print("Return Eligible")
# else:
#     print("Return Not Eligible")

# 9Q.
# List of order amounts
# orders = [2500, 60000, 4500, 52000, 3000]
# for order in orders:
#     if order > 50000:
#         print(order)

# 10Q.
# prices = [1000, 2000, 3000]
# for price in prices:
#     discount_price = price - (price * 5 / 100)
#     print(discount_price)

# 11Q.
# Orders = [50000, 25000, 100000, 110000]
# count = 0
# for amount in Orders:
#     if amount > 100000:
#      count = count + 1
#     print("orders are above 1,00,000",  count)

# 12Q.
# attempt = 1
# while attempt <= 3:
#  print("Payment retry attempt", attempt)
#  attempt = attempt + 1

# 13Q.
# attempt = 1
# Status = "pending"
# while Status != "Delivered" and attempt <= 5:
#  print("Checking Order Status ...")
#  if attempt == 4:
#     Status = "Delivered"
#  attempt = attempt + 1
#  print("final status = ", Status)

# 14Q.
# stock = 20
# while stock <= 100:
#       print("Current stock", stock)
#       stock = stock + 20
# print("stock is greater than 100")

# 15Q.
# orders = [ {"order_id": 101, "amount": 15000, "status": "Active"},
#     {"order_id": 102, "amount": 20000, "status": "Cancelled"},{"order_id": 103, "amount": 60000, "status": "Active"} ]
# premium_count = 0
# for order in orders:
#     if order["status"] == "Cancelled":
#         continue
#     if order["amount"] > 50000:
#         print("Order", order["order_id"], "is Premium")
#         premium_count = premium_count + 1
#     else:
#         print("Order", order["order_id"], "is Regular")
# print("Total Premium Orders =", premium_count)
# Out:
# Final Payable Amount = 13275.0
