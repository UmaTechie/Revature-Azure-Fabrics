# %%
import csv
import json

# SAMPLE DATA FOR CSV
# csv_products = [
#     [101, "Laptop", "Electronics", 75000, 10],
#     [102, "Mouse", "Accessories", 800, 50],
#     [103, "Keyboard", "Accessories", 1500, 30]
# ]

# SAMPLE DATA FOR JSON

json_products = [
    {"id": 101, "name": "Laptop", "category": "Electronics", "price": 75000, "quantity": 10},
    {"id": 102, "name": "Mouse", "category": "Accessories", "price": 800, "quantity": 50},
    {"id": 103, "name": "Keyboard", "category": "Accessories", "price": 1500, "quantity": 30},
    {"id": 104, "name": "Mobile", "category": "Electronics", "price": 25000, "quantity": 15},
    {"id": 105, "name": "Headphones", "category": "Accessories", "price": 2000, "quantity": 20}
]

#1. Write Products into CSV File
# with open("products.csv", "w", newline="") as file:
#     writer = csv.writer(file)
#     writer.writerow(["ID", "Name", "Category", "Price", "Quantity"])
#     writer.writerows(csv_products)
# print("CSV File Created Successfully")

#2. Read Data from CSV File
# print("Reading CSV File")
# with open("products.csv", "r") as file:
#     reader = csv.reader(file)
#     for row in reader:
#         print(row)

#3. Delete Product where id == 103
# updated_products = []
# with open("products.csv", "r") as file:
#     reader = csv.reader(file)
#     for row in reader:
#         # Keep header
#         if row[0] == "ID":
#             updated_products.append(row)
#         # Keep rows except ID 103
#         elif row[0] != "103":
#             updated_products.append(row)
# with open("products.csv", "w", newline="") as file:
#     writer = csv.writer(file)
#     writer.writerows(updated_products)
# print("Product 103 Deleted from CSV")

#4. Display Products with Price Greater than 5000
# print("Products Price Greater than 5000")
# with open("products.csv", "r") as file:
#     reader = csv.reader(file)
#     next(reader)   # Skip header
#     for row in reader:
#         price = int(row[3])
#         if price > 5000:
#             print(row)

#5. Write Products into JSON File
# with open("products.json", "w") as file:
#     json.dump(json_products, file, indent=4)
# print("JSON File Created Successfully")

#6. Read Data from JSON File
# print("Reading JSON File")
# with open("products.json", "r") as file:
#     data = json.load(file)
#     for product in data:
#         print(product)

#7. Delete Product where id == 102
# with open("products.json", "r") as file:
#     data = json.load(file)
# updated_data = []
# for product in data:
#     if product["id"] != 102:
#         updated_data.append(product)
# with open("products.json", "w") as file:
#     json.dump(updated_data, file, indent=4)
# print("Product 102 Deleted from JSON")

#8. Update Laptop Quantity to 25
# with open("products.json", "r") as file:
#     data = json.load(file)
# for product in data:
#     if product["name"] == "Laptop":
#         product["quantity"] = 25
# with open("products.json", "w") as file:
#     json.dump(data, file, indent=4)
# print("Laptop Quantity Updated")

#9. Display Electronics Products Only
# print("Electronics Products")
# with open("products.json", "r") as file:
#     data = json.load(file)
#     for product in data:
#         if product["category"] == "Electronics":
#             print(product)

#10. Append New Product to CSV
# new_product_csv = [106, "Monitor", "Electronics", 12000, 8]
# with open("products.csv", "a", newline="") as file:
#     writer = csv.writer(file)
#     writer.writerow(new_product_csv)
# print("Monitor Added to CSV")

#11. Append New Product to JSON
# new_product_json = {"id": 106, "name": "Monitor", "category": "Electronics", "price": 12000, "quantity": 8}
# with open("products.json", "r") as file:
#     data = json.load(file)
# data.append(new_product_json)
# with open("products.json", "w") as file:
#     json.dump(data, file, indent=4)
# print("Monitor Added to JSON")
# Out:
# Monitor Added to JSON
