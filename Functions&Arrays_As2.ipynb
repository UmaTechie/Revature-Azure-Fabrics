# %%
# List used for all problems
# numbers = [45, 12, 78, 34, 78, 90, 12, 56, 23, 45]
# 1. Array Sum
# def array_sum(num_list):
#     total = 0
#     for num in num_list:
#         total = total + num
#     return total
# print("1. Sum of elements =", array_sum(numbers))

# 2. Maximum Element
# def find_maximum(num_list):
#     largest = num_list[0]
#     for num in num_list:
#         if num > largest:
#             largest = num
#     return largest
# print("2. Largest element =", find_maximum(numbers))

# 3. Even Numbers Counter
# def count_even_numbers(num_list):
#     count = 0
#     for num in num_list:
#         if num % 2 == 0:
#             count = count + 1
#     return count
# print("3. Even numbers count =", count_even_numbers(numbers))

# 4. Reverse Array
# def reverse_array(num_list):
#     reversed_list = []
#     for index in range(len(num_list) - 1, -1, -1):
#         reversed_list.append(num_list[index])
#     return reversed_list
# print("4. Reversed list =", reverse_array(numbers))

# 5. Search Element
# def search_element(num_list, target):
#     for index in range(len(num_list)):
#         if num_list[index] == target:
#             return index
#     return -1
# print("5. Index of 90 =", search_element(numbers, 90))

# 6. Palindrome List
# def check_palindrome(num_list):
#     reversed_list = reverse_array(num_list)
#     if num_list == reversed_list:
#         return True
#     else:
#         return False
# print("6. Is palindrome =", check_palindrome(numbers))

# 7. Second Largest Number
# def find_second_largest(num_list):
#     largest = second_largest = -99999
#     for num in num_list:
#         if num > largest:
#             second_largest = largest
#             largest = num
#         elif num > second_largest and num != largest:
#             second_largest = num
#     return second_largest
# print("7. Second largest number =", find_second_largest(numbers))

# 8. Duplicate Elements
# def find_duplicates(num_list):
#     duplicates = []
#     for num in num_list:
#         if num_list.count(num) > 1 and num not in duplicates:
#             duplicates.append(num)
#     return duplicates
# print("8. Duplicate elements =", find_duplicates(numbers))

# 9. Function for Student Marks
# student_marks = [85, 90, 78, 92, 88]
# def analyze_marks(marks):
#     total = 0
#     for mark in marks:
#         total = total + mark
#     average = total / len(marks)
#     highest = marks[0]
#     lowest = marks[0]
#     for mark in marks:
#         if mark > highest:
#             highest = mark
#         if mark < lowest:
#             lowest = mark
#     return average, highest, lowest
# average, highest, lowest = analyze_marks(student_marks)
# print("9. Average marks =", average)
# print("   Highest marks =", highest)
# print("   Lowest marks =", lowest)
