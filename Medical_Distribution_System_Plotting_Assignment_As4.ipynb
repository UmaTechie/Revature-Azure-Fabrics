# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Creating Medical Distribution Dataset
medical_data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'],
    'Medicine_Distributed': [1200, 1500, 1800, 1700, 2100, 2500],
    'Hospital_Orders': [30, 45, 50, 48, 60, 75],
    'Delivery_Time': [5, 4, 6, 5, 3, 2],
    'Revenue': [50000, 65000, 72000, 70000, 85000, 95000]}
df = pd.DataFrame(medical_data)
print(df)

# 1.Line Chart for Medicine Distribution
# plt.figure(figsize=(8,5))
# plt.plot(df['Month'], df['Medicine_Distributed'])
# plt.title("Medicine Distribution Over Months")
# plt.xlabel("Month")
# plt.ylabel("Medicine Distributed")
# plt.grid(True)
# plt.savefig("line_chart1.png")
# plt.show()

#2. Line Chart for Revenue
# plt.figure(figsize=(8,5))
# plt.plot(df['Month'], df['Revenue'])
# plt.title("Monthly Revenue Growth")
# plt.xlabel("Month")
# plt.ylabel("Revenue")
# plt.grid(True)
# plt.savefig("line_chart2.png")
# plt.show()

#3&4. Multiple Line Charts
# plt.figure(figsize=(8,5))
# plt.plot(df['Month'],
#          df['Medicine_Distributed'],
#          marker='o',
#          label='Medicine Distributed')
# plt.plot(df['Month'],
#          df['Hospital_Orders'],
#          marker='s',
#          label='Hospital Orders')
# plt.title("Medicine Distribution vs Hospital Orders")
# plt.xlabel("Month")
# plt.ylabel("Count")
# plt.legend()
# plt.grid(True)
# plt.savefig("line_chart3.png")
# plt.show()

#5. Vertical Bar Chart
# plt.figure(figsize=(8,5))
# plt.bar(df['Month'], df['Hospital_Orders'])
# plt.title("Hospital Orders by Month")
# plt.xlabel("Month")
# plt.ylabel("Orders")
# plt.savefig("bar_chart1.png")
# plt.show()

#6. Horizontal Bar Chart
# plt.figure(figsize=(8,5))
# plt.barh(df['Month'], df['Revenue'])
# plt.title("Revenue by Month")
# plt.xlabel("Revenue")
# plt.ylabel("Month")
# plt.savefig("bar_chart2.png")
# plt.show()

#7&8. Grouped Bar Chart
# x = np.arange(len(df['Month']))
# width = 0.35
# plt.figure(figsize=(8,5))
# plt.bar(x - width/2,
#         df['Medicine_Distributed'],
#         width,
#         label='Medicine Distributed')
# plt.bar(x + width/2,
#         df['Hospital_Orders'],
#         width,
#         label='Hospital Orders')
# plt.xticks(x, df['Month'])
# plt.title("Medicine Distributed vs Hospital Orders")
# plt.xlabel("Month")
# plt.ylabel("Values")
# plt.legend()
# plt.savefig("bar_chart3.png")
# plt.show()

#9. Scatter Plot
# plt.figure(figsize=(8,5))
# plt.scatter(df['Hospital_Orders'], df['Revenue'])
# plt.title("Hospital Orders vs Revenue")
# plt.xlabel("Hospital Orders")
# plt.ylabel("Revenue")
# plt.savefig("scatter1.png")
# plt.show()

#10. Scatter Plot
# plt.figure(figsize=(8,5))
# plt.scatter(df['Delivery_Time'], df['Revenue'])
# plt.title("Delivery Time vs Revenue")
# plt.xlabel("Delivery Time")
# plt.ylabel("Revenue")
# plt.savefig("scatter2.png")
# plt.show()

#11. Scatter Plot
# plt.figure(figsize=(8,5))
# plt.scatter(df['Medicine_Distributed'],
#             df['Hospital_Orders'])
# plt.title("Medicine Distributed vs Hospital Orders")
# plt.xlabel("Medicine Distributed")
# plt.ylabel("Hospital Orders")
# plt.savefig("scatter3.png")
# plt.show()

#12. Comments - Relationship Analysis
# print("Hospital Orders and Revenue show a Positive Relationship.")
# print("Delivery Time and Revenue show a Negative Relationship.")
# print("Medicine Distribution and Hospital Orders show a Positive Relationship.")

#13. Pie Chart - Medicine Distribution Percentage
# plt.figure(figsize=(7,7))
# plt.pie(df['Medicine_Distributed'],
#         labels=df['Month'],
#         autopct='%1.1f%%')
# plt.title("Medicine Distribution Percentage by Month")
# plt.savefig("pie_chart1.png")
# plt.show()

#14. Pie Chart - Revenue Contribution by Month
# plt.figure(figsize=(7,7))
# plt.pie(df['Revenue'],
#         labels=df['Month'],
#         autopct='%1.1f%%')
# plt.title("Revenue Contribution by Month")
# plt.savefig("pie_chart2.png")
# plt.show()

# #15&16. Finding highest revenue month
# max_index = df['Revenue'].idxmax()
# explode = [0, 0, 0, 0, 0, 0]
# explode[max_index] = 0.2
# plt.figure(figsize=(7,7))
# plt.pie(df['Revenue'],
#         labels=df['Month'],
#         autopct='%1.1f%%',
#         explode=explode)
# plt.title("Highest Revenue Month Highlighted")
# plt.savefig("pie_chart3.png")
# plt.show()

#17. Revenue Trend with data values
# plt.figure(figsize=(8,5))
# plt.plot(df['Month'],
#          df['Revenue'],
#          marker='o')
# for i, value in enumerate(df['Revenue']):
#     plt.text(i, value, str(value))
# plt.title("Revenue Trend with Values")
# plt.xlabel("Month")
# plt.ylabel("Revenue")
# plt.grid(True)
# plt.savefig("bonus_chart.png")
# plt.show()
# Out:
#   Month  Medicine_Distributed  Hospital_Orders  Delivery_Time  Revenue
# 0   Jan                  1200               30              5    50000
# 1   Feb                  1500               45              4    65000
# 2   Mar                  1800               50              6    72000
# 3   Apr                  1700               48              5    70000
# 4   May                  2100               60              3    85000
# 5   Jun                  2500               75              2    95000
